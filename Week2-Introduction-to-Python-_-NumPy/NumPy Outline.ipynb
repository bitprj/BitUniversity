# %% [markdown]
# # SECTIONS
#
# ## Creating Arrays
#
# ## Indexing
#
# ## Slicing
#
# ## Data Types
#
# ## Copy, View
#
# ## Shape (Not whole section, but mini?)
#
# ## Reshaping Arrays
#
# ## Iterating Arrays
#
# ## Join, Split
#
# ## Search, Sort, Filter
#
# ## Random (Any distributions?)
#
# ## Universal Functions
#   1. Vectorization
#   2.This is where we talk about cumsum()
