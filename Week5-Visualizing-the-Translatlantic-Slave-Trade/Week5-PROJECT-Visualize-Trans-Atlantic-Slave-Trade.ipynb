# %% [markdown]
# ## Connecting to Your Google Drive

# %%
# Start by connecting google drive into google colab

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/DigitalHistory"
# Out:
# 'List Operations.ipynb'
# 'String Operations.ipynb'
#  tmp
# 'Topics For Later Sections.gdoc'
# 'Week2-Introduction-to-Python-&-NumPy'
#  Week3-Introduction-to-Open-Data-Importing-Data-and-Basic-Data-Wrangling
#  Week4-Introduction-to-Data-Visualization-Graphs-Charts-and-Tables
#  Week5-Visualizing-the-Translatlantic-Slave-Trade
#  Week6-Advanced-Data-Wrangling-using-Pandas
#  Week7-Intro-to-Statistical-Analysis-and-Methods
#  Week8-PROJECT-Analyze-Trans-Atlantic-Slave-Trade.ipynb
#  Week8-Statistical-Visualization-using-Seaborn-and-Pandas

# %%
cd "/content/gdrive/My Drive/DigitalHistory/tmp/trans-atlantic-slave-trade"
# Out:
# /content/gdrive/My Drive/DigitalHistory/tmp/trans-atlantic-slave-trade

# %%
ls
# Out:
# __MACOSX/  trans-atlantic-slave-trade.csv
# tmp/       trans-atlantic-slave-trade.csv.zip

# %% [markdown]
# ## Import Libraries and unpack file

# %%
import pandas as pd
import zipfile

# %%
file_location = 'trans-atlantic-slave-trade.csv.zip'

zip_ref = zipfile.ZipFile(file_location,'r')
zip_ref.extractall('tmp/trans-atlantic-slave-trade')
zip_ref.close()

# %% [markdown]
# ## Load file

# %%
df = pd.read_csv('tmp/trans-atlantic-slave-trade/trans-atlantic-slave-trade.csv')

# %% [markdown]
# ## Observing the Dataset using Pandas

# %% [markdown]
# ## Basic info about the dataset
# Now, the dataset is loaded as a dataframe 'df'
#
# ### head()
# Let's check what columns this file has by calling 'head()' function.
# It returns first n rows, and it's useful to see the dataset at a quick glance.
#
# By default, the head() function returns the first 5 rows.
#
# You can specify the number of rows to display by calling df.head(number)

# %%
df.head()
# Out:
#    Voyage ID Vessel name  ... Slaves arrived at 1st port   Captain's name
# 0      81711      Hannah  ...                      390.0     Smith, Bryan
# 1      81712      Hannah  ...                      351.0  Wilson, Charles
# 2      81713      Hannah  ...                      303.0  Wilson, Charles
# 3      81714      Hannah  ...                      316.0   Young, William
# 4      81715      Hannah  ...                      331.0   Young, William
#
# [5 rows x 8 columns]

# %% [markdown]
# ### info()
# This will return all of the column names and its types. This function is useful to get the idea of what the dataframe is like.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36110 entries, 0 to 36109
# Data columns (total 8 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Voyage ID                                                                          36110 non-null  int64
#  1   Vessel name                                                                        36108 non-null  object
#  2   Voyage itinerary imputed port where began (ptdepimp) place                         31646 non-null  object
#  3   Voyage itinerary imputed principal place of slave purchase (mjbyptimp)             34420 non-null  object
#  4   Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place  31846 non-null  object
#  5   Year of arrival at port of disembarkation                                          36110 non-null  int64
#  6   Slaves arrived at 1st port                                                         18364 non-null  float64
#  7   Captain's name                                                                     32054 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.2+ MB

# %% [markdown]
# ### describe()
# describe() is used to view summary statistics of numeric columns. This will help you to have general idea of the dataset.

# %%
df.describe()
# Out:
#            Voyage ID  ...  Slaves arrived at 1st port
# count   36110.000000  ...                18364.000000
# mean    42861.336278  ...                  275.718743
# std     72705.501393  ...                  159.102320
# min         1.000000  ...                    0.000000
# 25%     16135.250000  ...                  157.000000
# 50%     32540.500000  ...                  253.000000
# 75%     50322.750000  ...                  370.250000
# max    900237.000000  ...                 1700.000000
#
# [8 rows x 3 columns]

# %% [markdown]
# ### shape
# To see the size of the dataset, we can use shape function, which returns the number of rows and columns in a format of (#rows, #columns)

# %%
df.shape
# Out:
# (36110, 8)

# %% [markdown]
# ### Remove NaN values
#
# Before we dive into the dataset, let's learn how to remove NaN (Null) values.
# * df.dropna(): drop the rows where at least one of the elements is missing.
# * df.dropna(how='all'): drop the rows where all of the elements are missing.
# * df.dropna(subset=['Voyage ID', 'Vessel name']): define in which columns to look for missing values.

# %%
# if we drop the rows with at least one missing element.
df.dropna().shape
# Out:
# (15299, 8)

# %%
# if we drop the rows with all elements missing.
df.dropna(how='all').shape
# Out:
# (36110, 8)

# %%
# define in which columns to look for missing values.
df.dropna(subset=['Voyage ID', 'Vessel name']).shape
# Out:
# (36108, 8)

# %% [markdown]
# In the trans_atlantic_slave dataset, there are only two rows that are missing 'Voyage ID' and 'Vessel name.' (36110-36108 = 2)
#
# If you want to update the current dataframe with the valid entries only, then you can call (inplace = True)
#
# The code below will keep the updated dataset in the same variable.

# %%
df.dropna(subset=['Voyage ID', 'Vessel name'], inplace=True)

# %% [markdown]
# ## Select columns to work with
#
# If you are interested in a few columns to do the data analysis, you can select a specific subset of columns using two methods:
#
# 1. by index location
# 2. by column names

# %%
# by index location
df_index = df.iloc[: , [0,1,2,3]].copy()
df_index
# Out:
#        Voyage ID  ... Voyage itinerary imputed principal place of slave purchase (mjbyptimp)
# 0          81711  ...                                            Calabar
# 1          81712  ...                                        New Calabar
# 2          81713  ...  Bight of Biafra and Gulf of Guinea Islands, po...
# 3          81714  ...                                              Bonny
# 4          81715  ...                                        Congo River
# ...          ...  ...                                                ...
# 36105      80358  ...                          Africa., port unspecified
# 36106      81265  ...                        Bance Island (Ben's Island)
# 36107      81266  ...  West Central Africa and St. Helena, port unspe...
# 36108      83426  ...                                              Bonny
# 36109      83427  ...                                            Calabar
#
# [36108 rows x 4 columns]

# %%
# by column names
df_col_names = df[['Voyage ID', 'Vessel name', 'Slaves arrived at 1st port']]
df_col_names
# Out:
#        Voyage ID   Vessel name  Slaves arrived at 1st port
# 0          81711        Hannah                       390.0
# 1          81712        Hannah                       351.0
# 2          81713        Hannah                       303.0
# 3          81714        Hannah                       316.0
# 4          81715        Hannah                       331.0
# ...          ...           ...                         ...
# 36105      80358         Ariel                         NaN
# 36106      81265         Ellis                       263.0
# 36107      81266         Ellis                       303.0
# 36108      83426  Royal Edward                       396.0
# 36109      83427  Royal Edward                       280.0
#
# [36108 rows x 3 columns]

# %% [markdown]
# ## Filter Dataset using criteria
#
# Often times, you are interested in working with specific rows that meet the certain criteria.
#
# Let's say that we only want to work with the data since 1800.
#
# Within the 'loc' function, you need to specify the criteria with a column name.

# %%
df_since_1800=df.loc[df['Year of arrival at port of disembarkation'] > 1800]
df_since_1800
# Out:
#        Voyage ID  ...                                     Captain's name
# 12         81727  ...                                      Brade, Thomas
# 17         81732  ...                                    Ainsworth, John
# 20         81735  ...                      Clarke, James<br/> Sutherland
# 21         81736  ...                                Sutherland, Stewart
# 22         81737  ...                           Clark, James<br/> Duncan
# ...          ...  ...                                                ...
# 36101      47527  ...  Maria, José<br/> Gonçalves, João<br/> Guimarãe...
# 36102      49000  ...  Medões, Bernardo da Silva<br/> Queiróz, Manoel...
# 36106      81265  ...                                      Soutar, James
# 36107      81266  ...                                        Roach, John
# 36109      83427  ...                                    Griffiths, John
#
# [10923 rows x 8 columns]

# %% [markdown]
# Let's select the dataset where the 'Year of arrival at port of disembarkation' is 1800.

# %%
df_in_1800=df.loc[df['Year of arrival at port of disembarkation'] == 1800]
df_in_1800
# Out:
#        Voyage ID  ...                                     Captain's name
# 11         81726  ...                                     Maginnis, John
# 2286       19101  ...  Garcia, Francisco Correa<br/> Firme, Manoel Ca...
# 2287       19102  ...                           Couto, Antônio Xavier do
# 2288       19103  ...                                  Viana, Paulo José
# 2289       19104  ...                             Firme, Antônio Caetano
# ...          ...  ...                                                ...
# 35735      80745  ...                                       Clark, James
# 35745      80757  ...                                     Morrison, John
# 35784      80802  ...                                    Crooker, Thomas
# 35825     900040  ...                                                NaN
# 36108      83426  ...                                    Bushell, Thomas
#
# [295 rows x 8 columns]

# %% [markdown]
# ## Aggregation
#
# Aggregation is the process of combining things.
#
# Some examples of aggregation are sum, minimum, maximum, count, average, standard deviation, etc.

# %% [markdown]
# # Visualizing the Trans-Atlantic Slave Trade
#
# ## About the Dataset
#
# - The dataset approximatey 36,110 trans-Atlantic voyages.
# - The estimates suggest around 12,520,000 captives departed Afriva to the Americas.
#
# - Not all 36,000 voyages in the database carried slaves from Africa.
# - A total of 633 voyages (1.8%) never reached the African coast because they were lost at sea, captured or suffered some other misfortune.
# - The database also contains records of 34,106 voyages that disembarked slaves, or could have done so (in other words, for some of these we do not know the outcome of the voyage).
#
# - The latter group comprised mainly ships captured in the nineteenth century which were taken to Sierra Leone and St. Helena as part of the attempt to suppress the trade.
#
# **For this lab we we will be verifying these statements and visualize them to be able to understand our dataset better**

# %% [markdown]
# **[ADD EXPLANATION FOR HEAD]**
#
# ### Columns

# %%
my_list = list(df)
print(my_list)
# Out:
# ['Voyage ID', 'Vessel name', 'Voyage itinerary imputed port where began (ptdepimp) place', 'Voyage itinerary imputed principal place of slave purchase (mjbyptimp) ', 'Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place', 'Year of arrival at port of disembarkation', 'Slaves arrived at 1st port', "Captain's name"]

# %% [markdown]
# Lets go step by step  and first visualize the voyage ID

# %%
df.plot(x = 'Year of arrival at port of disembarkation',y = 'Slaves arrived at 1st port', kind = 'scatter',c = 'Slaves arrived at 1st port',title = 'Year of arrival at port of disembarkation vs Slaves arrived at 1st port', alpha = 0.3,cmap = plt.get_cmap('jet'),colorbar = True,figsize = (20,10))

# %%
df_most_voyages = df.loc[df['Slaves arrived at 1st port'] > 750]
df_most_voyages
# Out:
#        Voyage ID  ...        Captain's name
# 300         2116  ...                   NaN
# 345         2161  ...                   NaN
# 407         2224  ...         Eguiguira, T.
# 427         2245  ...                   NaN
# 446         2264  ...  Simões, Jesuíno José
# ...          ...  ...                   ...
# 35035      31782  ...      Gourrège, Pierre
# 35581      32353  ...   Corbie<br/> Micheau
# 35601      32375  ...        Bouyer, Alexis
# 35605      32379  ...               Lesenne
# 36099      46254  ...                   NaN
#
# [152 rows x 8 columns]

# %% [markdown]
# ### Journey Start

# %%
ships_from_La_Rochelle = df.loc[df['Voyage itinerary imputed port where began (ptdepimp) place'] == 'La Rochelle']
ships_from_La_Rochelle
# Out:
#        Voyage ID  ...         Captain's name
# 961         2836  ...  Luzet, Michel Etienne
# 4662       21593  ...             Ramé, Jean
# 4704       21871  ...                    NaN
# 4705       21872  ...                 Breman
# 4706       21873  ...          Vigneau, Jean
# ...          ...  ...                    ...
# 35673      32447  ...            Carry, Alex
# 35674      32448  ...      Bourgine, Antoine
# 35675      32449  ...                 Dufaud
# 36089      33511  ...       Andrieu, Bernabe
# 36090      33515  ...       Heispeneau, G de
#
# [483 rows x 8 columns]

# %%
ships_from_La_Rochelle.plot(x = 'Year of arrival at port of disembarkation',y = 'Slaves arrived at 1st port', kind = 'scatter',xticks = [1750,1800],c = 'Slaves arrived at 1st port',title = 'Year of arrival at port of disembarkation vs Slaves arrived at 1st port [LA ROCHELLE]', alpha = 0.9,cmap = plt.get_cmap('Reds'),colorbar = True,figsize = (20,10))

# %%
ships_from_London = df.loc[df['Voyage itinerary imputed port where began (ptdepimp) place'] == 'London']
ships_from_London
# Out:
#        Voyage ID  ...                   Captain's name
# 7          81718  ...                 Banfield, Joseph
# 18         81733  ...                     Clark, James
# 19         81734  ...                     Clark, James
# 20         81735  ...    Clarke, James<br/> Sutherland
# 21         81736  ...              Sutherland, Stewart
# ...          ...  ...                              ...
# 35746      80759  ...                  Erskine, Andrew
# 35747      80760  ...                         Pratt, T
# 35764      80781  ...            Anderson, Christopher
# 35765      80782  ...                    Tyack, Joseph
# 36011      15178  ...  Veer, Thomas<br/> Clegg, Joseph
#
# [3126 rows x 8 columns]

# %%
ships_from_London.plot(x = 'Year of arrival at port of disembarkation',y = 'Slaves arrived at 1st port', kind = 'scatter',xticks = [1750,1810],c = 'Slaves arrived at 1st port',title = 'Year of arrival at port of disembarkation vs Slaves arrived at 1st port [LONDON]', alpha = 0.9,cmap = plt.get_cmap('Reds'),colorbar = True,figsize = (20,10))

# %% [markdown]
# ### Captains

# %%
df_captain_Maginnis = df.loc[df['Captain\'s name'] == 'Maginnis, John']
df_captain_Maginnis
# Out:
#        Voyage ID  Vessel name  ... Slaves arrived at 1st port  Captain's name
# 11         81726    Harlequin  ...                      268.0  Maginnis, John
# 143        83729    Telegraph  ...                      135.0  Maginnis, John
# 16817      81998         Jane  ...                        NaN  Maginnis, John
# 21766      82352  Lord Nelson  ...                      258.0  Maginnis, John
# 21767      82353  Lord Nelson  ...                      316.0  Maginnis, John
# 23519      83629      Stephen  ...                        NaN  Maginnis, John
# 30710      18243         Dick  ...                      172.0  Maginnis, John
#
# [7 rows x 8 columns]

# %%
df_captain_Maginnis = df.loc[df['Captain\'s name'] == 'Maginnis, John']
df_captain_Maginnis

# %% [markdown]
# ### Trips made to Rio

# %%
df_Rio_Landing = df.loc[df['Voyage itinerary imputed principal port of slave disembarkation (mjslptimp) place'] == 'Rio de Janeiro']
df_Rio_Landing
# Out:
#        Voyage ID  ...            Captain's name
# 160          978  ...               Viana, João
# 161          979  ...  Santos, José Freitas dos
# 162          980  ...            Roberto, Vítor
# 163          981  ...   Ferreira, Luiz da Costa
# 164          982  ...    Silva, João Antônio da
# ...          ...  ...                       ...
# 36005     900233  ...                       NaN
# 36006     900234  ...                       NaN
# 36008     900236  ...                       NaN
# 36009     900237  ...                       NaN
# 36058      30038  ...            Dansaint, Jean
#
# [2887 rows x 8 columns]

# %%
df_Rio_Landing['Slaves arrived at 1st port'].hist()

# %% [markdown]
# # Bonus

# %%
# !pip install geopandas

# %%
# !pip install googlemaps
# Out:
# Collecting googlemaps
#   Downloading https://files.pythonhosted.org/packages/cb/87/5cbe65cd19defe67472db7afd84963a77fbbbe4a764320a67d4a64282b61/googlemaps-4.4.1.tar.gz
# Requirement already satisfied: requests<3.0,>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from googlemaps) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0,>=2.20.0->googlemaps) (2.10)
# Building wheels for collected packages: googlemaps
#   Building wheel for googlemaps (setup.py) ... done
#   Created wheel for googlemaps: filename=googlemaps-4.4.1-cp36-none-any.whl size=37819 sha256=600a88c032d3a8858941bd0836c7358342148c29094394371c8e017d59adb8be
#   Stored in directory: /root/.cache/pip/wheels/5c/ec/b9/9d0c26b80d7dcf16496c82e8108c93186c6d4df097a41bba4f
# Successfully built googlemaps
# Installing collected packages: googlemaps
# Successfully installed googlemaps-4.4.1

# %%
from googlemaps import Client as GoogleMaps
import pandas as pd

# %%
gmaps = GoogleMaps('AIzaSyASQlsj2mz9dfYsQsyCWFMmGoo33RSCOiA')

# %%
df
# Out:
#        Voyage ID   Vessel name  ... Slaves arrived at 1st port   Captain's name
# 0          81711        Hannah  ...                      390.0     Smith, Bryan
# 1          81712        Hannah  ...                      351.0  Wilson, Charles
# 2          81713        Hannah  ...                      303.0  Wilson, Charles
# 3          81714        Hannah  ...                      316.0   Young, William
# 4          81715        Hannah  ...                      331.0   Young, William
# ...          ...           ...  ...                        ...              ...
# 36105      80358         Ariel  ...                        NaN            Young
# 36106      81265         Ellis  ...                      263.0    Soutar, James
# 36107      81266         Ellis  ...                      303.0      Roach, John
# 36108      83426  Royal Edward  ...                      396.0  Bushell, Thomas
# 36109      83427  Royal Edward  ...                      280.0  Griffiths, John
#
# [36110 rows x 8 columns]

# %%
addresses = df.filter(['Voyage itinerary imputed port where began (ptdepimp) place'], axis=1)
addresses.head()
# Out:
#   Voyage itinerary imputed port where began (ptdepimp) place
# 0                                          Liverpool
# 1                                          Liverpool
# 2                                          Liverpool
# 3                                          Liverpool
# 4                                          Liverpool

# %%
addresses['long'] = ""
addresses['lat'] = ""

# %%
addresses
# Out:
#       Voyage itinerary imputed port where began (ptdepimp) place long lat
# 0                                              Liverpool
# 1                                              Liverpool
# 2                                              Liverpool
# 3                                              Liverpool
# 4                                              Liverpool
# ...                                                  ...          ...  ..
# 36105                                          Liverpool
# 36106                                          Liverpool
# 36107                                          Liverpool
# 36108                                          Liverpool
# 36109                                          Liverpool
#
# [36110 rows x 3 columns]

# %%
import time
for x in range(len(addresses)):
    try:
        time.sleep(1) # to add delay in case of large DFs
        geocode_result = gmaps.geocode(addresses['Voyage itinerary imputed port where began (ptdepimp) place'][x])
        addresses['lat'][x] = geocode_result[0]['geometry']['location'] ['lat']
        addresses['long'][x] = geocode_result[0]['geometry']['location']['lng']
    except IndexError:
        print("Address was wrong...")
    except Exception as e:
        print("Unexpected error occurred.", e )
addresses.head()
# Out:
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
# Address was wrong...
