# %% [markdown]
# ## <div align = "center">Homework 6</div>
# # <div align = "center">Flight Delay Data</div>

# %% [markdown]
# **Welcome to Homework 6!** In this homework you will be using techniques you learned through Week 6. The purpose of this homework for you to do data manipulation with ```Pandas``` and to express your observations.
#
# Feel free to refer back to week 6 tutorial notebook and ask questions on Piazza!

# %% [markdown]
# ### Grading
#
# There are a total of 5 questions and each question is worth 2-5 points.

# %% [markdown]
# ### Import library

# %%
import pandas as pd

# %% [markdown]
# ### Load file

# %%
url = 'https://raw.githubusercontent.com/bitprj/DigitalHistory/master/Week6-Advanced-Data-Wrangling-using-Pandas/data/Jan_2020_ontime.csv'
df = pd.read_csv(url)


url = 'https://raw.githubusercontent.com/bitprj/DigitalHistory/master/Week6-Advanced-Data-Wrangling-using-Pandas/data/airline_names.xlsx'
airline = pd.read_excel(url)


url = 'https://raw.githubusercontent.com/bitprj/DigitalHistory/master/Week6-Advanced-Data-Wrangling-using-Pandas/data/airline_delay_causes.csv'
airport_codes = pd.read_csv(url)
# Out:
#         year   month carrier          carrier_name airport  \
# 0       2004       1      DL  Delta Air Lines Inc.     PBI
# 1       2004       1      DL  Delta Air Lines Inc.     PDX
# 2       2004       1      DL  Delta Air Lines Inc.     PHL
# 3       2004       1      DL  Delta Air Lines Inc.     PHX
# 4       2004       1      DL  Delta Air Lines Inc.     PIT
# ...      ...     ...     ...                   ...     ...
# 279177  2019       1      MQ             Envoy Air     RIC
# 279178  2019       1      MQ             Envoy Air     ROA
# 279179  2019       1      MQ             Envoy Air     ROC
# 279180  2019       1      MQ             Envoy Air     RST
# 279181  2019       1      MQ             Envoy Air     SAT
#
#                                              airport_name  arr_flights  \
# 0       West Palm Beach/Palm Beach, FL: Palm Beach Int...        650.0
# 1                    Portland, OR: Portland International        314.0
# ...

# %% [markdown]
# ## Homework Questions
#
# **Since this dataset has lots of information, feel free to select a set of columns to answer each question.**

# %% [markdown]
# ### Q1. Join ```df``` with ```airline``` and ```airport_codes```

# %% [markdown]
# ### Q2. Find out five largest airlines by the number of flights in January

# %% [markdown]
# ### Q3. Calculate cancellation percentages of the top 5 airlines.

# %% [markdown]
# ### Q4. Find out the percentage of flights that managed to arrive within 15 minutes even though the flight departed more than 15 minutes past scheduled departure time
#
# (Hint: you may use ```DEP_DEL15``` and ```ARR_DEL15``` indicators.)

# %% [markdown]
# ### Q5. Convert categorical column (airline code / name) to numerical column and plot data visualizations for each airline
