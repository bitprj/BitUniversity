# %% [markdown]
# <a href="https://colab.research.google.com/github/bitprj/BitU-3WBootCamp/blob/main/Week%202%20-%20Working%20with%20Data%20using%20Pandas/Week2_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <div align = "center">Homework 2</div>
# # <div align = "center">US Census Data</div>

# %% [markdown]
# **Welcome to Homework 2!**
#
# In this homework you will be using techniques you learned in Week 2. The purpose of this homework is for you to try data manipulation with ```Pandas``` and to express your observations.
#
# Feel free to refer back to week 2 tutorial notebook and ask questions on Piazza!

# %% [markdown]
# ### Grading

# %% [markdown]
# There are a total of ten questions and each question is worth 1 point.

# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
url = 'https://raw.githubusercontent.com/bitprj/DigitalHistory/master/Week3-Introduction-to-Open-Data-Importing-Data-and-Basic-Data-Wrangling/data/acs2017_county_data.csv'
df = pd.read_csv(url)
df
# Out:
#       CountyId        State  ... FamilyWork  Unemployment
# 0         1001      Alabama  ...        0.1           5.2
# 1         1003      Alabama  ...        0.1           5.5
# 2         1005      Alabama  ...        0.3          12.4
# 3         1007      Alabama  ...        0.3           8.2
# 4         1009      Alabama  ...        0.1           4.9
# ...        ...          ...  ...        ...           ...
# 3215     72145  Puerto Rico  ...        0.2          16.8
# 3216     72147  Puerto Rico  ...        0.0          12.8
# 3217     72149  Puerto Rico  ...        0.2          24.8
# 3218     72151  Puerto Rico  ...        0.0          25.4
# 3219     72153  Puerto Rico  ...        0.0          24.0
#
# [3220 rows x 37 columns]

# %% [markdown]
# ## Homework Questions

# %% [markdown]
# ### Q1. List out all column names of ```df```. (1 pt)

# %%
df.columns
# Out:
# Index(['CountyId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %% [markdown]
# ### Q2. Set ```CountyId``` as an index for ```df```. (1 pt)
#
# Hint: Use ```set_index``` and make changes in place.

# %%
df.set_index(keys='CountyId', inplace = True)
df
# Out:
#                 State               County  ...  FamilyWork  Unemployment
# CountyId                                    ...
# 1001          Alabama       Autauga County  ...         0.1           5.2
# 1003          Alabama       Baldwin County  ...         0.1           5.5
# 1005          Alabama       Barbour County  ...         0.3          12.4
# 1007          Alabama          Bibb County  ...         0.3           8.2
# 1009          Alabama        Blount County  ...         0.1           4.9
# ...               ...                  ...  ...         ...           ...
# 72145     Puerto Rico  Vega Baja Municipio  ...         0.2          16.8
# 72147     Puerto Rico    Vieques Municipio  ...         0.0          12.8
# 72149     Puerto Rico   Villalba Municipio  ...         0.2          24.8
# 72151     Puerto Rico    Yabucoa Municipio  ...         0.0          25.4
# 72153     Puerto Rico      Yauco Municipio  ...         0.0          24.0
#
# [3220 rows x 36 columns]

# %% [markdown]
# ### Q3 (a). Get the basic information about `df` using `info()` function. (0.5pt)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3220 entries, 1001 to 72153
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State             3220 non-null   object
#  1   County            3220 non-null   object
#  2   TotalPop          3220 non-null   int64
#  3   Men               3220 non-null   int64
#  4   Women             3220 non-null   int64
#  5   Hispanic          3220 non-null   float64
#  6   White             3220 non-null   float64
#  7   Black             3220 non-null   float64
#  8   Native            3220 non-null   float64
#  9   Asian             3220 non-null   float64
#  10  Pacific           3220 non-null   float64
#  11  VotingAgeCitizen  3220 non-null   int64
#  12  Income            3220 non-null   int64
#  13  IncomeErr         3220 non-null   int64
#  14  IncomePerCap      3220 non-null   int64
#  15  IncomePerCapErr   3220 non-null   int64
#  16  Poverty           3220 non-null   float64
#  17  ChildPoverty      3219 non-null   float64
#  18  Professional      3220 non-null   float64
#  19  Service           3220 non-null   float64
#  20  Office            3220 non-null   float64
#  21  Construction      3220 non-null   float64
#  22  Production        3220 non-null   float64
#  23  Drive             3220 non-null   float64
#  24  Carpool           3220 non-null   float64
#  25  Transit           3220 non-null   float64
#  26  Walk              3220 non-null   float64
#  27  OtherTransp       3220 non-null   float64
#  28  WorkAtHome        3220 non-null   float64
#  29  MeanCommute       3220 non-null   float64
#  30  Employed          3220 non-null   int64
#  31  PrivateWork       3220 non-null   float64
#  32  PublicWork        3220 non-null   float64
#  33  SelfEmployed      3220 non-null   float64
#  34  FamilyWork        3220 non-null   float64
#  35  Unemployment      3220 non-null   float64
# dtypes: float64(25), int64(9), object(2)
# memory usage: 930.8+ KB

# %% [markdown]
# ### Q3 (b). How many of the columns are numbers? (0.5pt)

# %%
34
# Out:
# 34

# %% [markdown]
# ### Q4. Select the following columns and save the dataframe as `df`. (1pt)
# #### 'State', 'County', 'TotalPop', 'Income', 'Unemployment', 'Employed', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome'

# %%
df = df[['State', 'County', 'TotalPop', 'Income', 'Unemployment', 'Employed', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome']]
df
# Out:
#                 State               County  ...  OtherTransp  WorkAtHome
# CountyId                                    ...
# 1001          Alabama       Autauga County  ...          1.3         2.5
# 1003          Alabama       Baldwin County  ...          1.1         5.6
# 1005          Alabama       Barbour County  ...          1.7         1.3
# 1007          Alabama          Bibb County  ...          1.7         1.5
# 1009          Alabama        Blount County  ...          0.4         2.1
# ...               ...                  ...  ...          ...         ...
# 72145     Puerto Rico  Vega Baja Municipio  ...          0.6         0.9
# 72147     Puerto Rico    Vieques Municipio  ...          0.0         1.7
# 72149     Puerto Rico   Villalba Municipio  ...          0.0         2.8
# 72151     Puerto Rico    Yabucoa Municipio  ...          1.8         0.1
# 72153     Puerto Rico      Yauco Municipio  ...          0.1         5.0
#
# [3220 rows x 12 columns]

# %% [markdown]
# ### Q5 (a). List out unique state names. (0.5pt)
# (Hint: Refer to Analysis of Unique Values section.)

# %%
df[['State']].drop_duplicates()
# Out:
#                          State
# CountyId
# 1001                   Alabama
# 2013                    Alaska
# 4001                   Arizona
# 5001                  Arkansas
# 6001                California
# 8001                  Colorado
# 9001               Connecticut
# 10001                 Delaware
# 11001     District of Columbia
# 12001                  Florida
# 13001                  Georgia
# 15001                   Hawaii
# 16001                    Idaho
# 17001                 Illinois
# 18001                  Indiana
# 19001                     Iowa
# 20001                   Kansas
# 21001                 Kentucky
# 22001                Louisiana
# 23001                    Maine
# 24001                 Maryland
# 25001            Massachusetts
# 26001                 Michigan
# 27001                Minnesota
# 28001              Mississippi
# 29001                 Missouri
# 30001                  Montana
# 31001                 Nebraska
# 32001                   Nevada
# 33001            New Hampshire
# 34001               New Jersey
# 35001               New Mexico
# 36001                 New York
# 37001           North Carolina
# 38001             North Dakota
# 39001                     Ohio
# 40001                 Oklahoma
# 41001                   Oregon
# 42001             Pennsylvania
# 44001             Rhode Island
# 45001           South Carolina
# 46003             South Dakota
# 47001                Tennessee
# 48001                    Texas
# 49001                     Utah
# 50001                  Vermont
# 51001                 Virginia
# 53001               Washington
# 54001            West Virginia
# 55001                Wisconsin
# 56001                  Wyoming
# 72001              Puerto Rico

# %% [markdown]
# ### Q5 (b). How many states are in the dataset? (0.5pt)

# %%
df['State'].nunique()
# Out:
# 52

# %% [markdown]
# ### Q6 (a). How many counties are there for each state? (0.5pt)
# (Hint: Use `size()` function.)

# %%
df.groupby(['State']).size()
# Out:
# State
# Alabama                  67
# Alaska                   29
# Arizona                  15
# Arkansas                 75
# California               58
# Colorado                 64
# Connecticut               8
# Delaware                  3
# District of Columbia      1
# Florida                  67
# Georgia                 159
# Hawaii                    5
# Idaho                    44
# Illinois                102
# Indiana                  92
# Iowa                     99
# Kansas                  105
# Kentucky                120
# Louisiana                64
# Maine                    16
# Maryland                 24
# Massachusetts            14
# Michigan                 83
# Minnesota                87
# Mississippi              82
# Missouri                115
# Montana                  56
# Nebraska                 93
# Nevada                   17
# New Hampshire            10
# New Jersey               21
# New Mexico               33
# New York                 62
# North Carolina          100
# North Dakota             53
# Ohio                     88
# Oklahoma                 77
# Oregon                   36
# Pennsylvania             67
# Puerto Rico              78
# Rhode Island              5
# South Carolina           46
# South Dakota             66
# Tennessee                95
# Texas                   254
# Utah                     29
# Vermont                  14
# Virginia                133
# Washington               39
# West Virginia            55
# Wisconsin                72
# Wyoming                  23
# dtype: int64

# %% [markdown]
# ### Q6 (b). Sort the state by the number of counties in each state. (0.5pt)

# %%
df.groupby(['State']).size().sort_values()
# Out:
# State
# District of Columbia      1
# Delaware                  3
# Rhode Island              5
# Hawaii                    5
# Connecticut               8
# New Hampshire            10
# Massachusetts            14
# Vermont                  14
# Arizona                  15
# Maine                    16
# Nevada                   17
# New Jersey               21
# Wyoming                  23
# Maryland                 24
# Utah                     29
# Alaska                   29
# New Mexico               33
# Oregon                   36
# Washington               39
# Idaho                    44
# South Carolina           46
# North Dakota             53
# West Virginia            55
# Montana                  56
# California               58
# New York                 62
# Louisiana                64
# Colorado                 64
# South Dakota             66
# Pennsylvania             67
# Alabama                  67
# Florida                  67
# Wisconsin                72
# Arkansas                 75
# Oklahoma                 77
# Puerto Rico              78
# Mississippi              82
# Michigan                 83
# Minnesota                87
# Ohio                     88
# Indiana                  92
# Nebraska                 93
# Tennessee                95
# Iowa                     99
# North Carolina          100
# Illinois                102
# Kansas                  105
# Missouri                115
# Kentucky                120
# Virginia                133
# Georgia                 159
# Texas                   254
# dtype: int64

# %% [markdown]
# ### Q6 (c). What are the states with the least county and the most county?

# %%
print("State with the least county: District of Columbia")
print("State with the most county: Texas")
# Out:
# State with the least county: District of Columbia
# State with the most county: Texas

# %% [markdown]
# ### Q7 (a). Select the rows where ```Unemployment``` is greater than 10. (0.5 pt)
#
# Hint: Use ```df.loc[]```.

# %% [markdown]
# #### Code:

# %%
df.loc[df['Unemployment'] > 10]
# Out:
#                 State               County  ...  OtherTransp  WorkAtHome
# CountyId                                    ...
# 1005          Alabama       Barbour County  ...          1.7         1.3
# 1011          Alabama       Bullock County  ...          1.7         3.0
# 1015          Alabama       Calhoun County  ...          1.1         3.2
# 1025          Alabama        Clarke County  ...          2.7         0.9
# 1035          Alabama       Conecuh County  ...          0.4         1.7
# ...               ...                  ...  ...          ...         ...
# 72145     Puerto Rico  Vega Baja Municipio  ...          0.6         0.9
# 72147     Puerto Rico    Vieques Municipio  ...          0.0         1.7
# 72149     Puerto Rico   Villalba Municipio  ...          0.0         2.8
# 72151     Puerto Rico    Yabucoa Municipio  ...          1.8         0.1
# 72153     Puerto Rico      Yauco Municipio  ...          0.1         5.0
#
# [346 rows x 12 columns]

# %% [markdown]
# ### Q7 (b). How many counties have ```Unemployment``` > 10? Type your answer in the Answer section. (0.5 pt)
#
# Hint: Look at how many rows Q3 (a) displays.

# %% [markdown]
# #### Answer:

# %%
346
# Out:
# 346

# %% [markdown]
# ### Q8 (a). Find the state with the largest population. (0.5 pt)
#
# Hint: Use `groupby` function.

# %% [markdown]
# #### Code:

# %%
df.groupby(['State'])['TotalPop'].sum().sort_values()
# Out:
# State
# Wyoming                   583200
# Vermont                   624636
# District of Columbia      672391
# Alaska                    738565
# North Dakota              745475
# South Dakota              855444
# Delaware                  943732
# Montana                  1029862
# Rhode Island             1056138
# Maine                    1330158
# New Hampshire            1331848
# Hawaii                   1421658
# Idaho                    1657375
# West Virginia            1836843
# Nebraska                 1893921
# New Mexico               2084828
# Nevada                   2887725
# Kansas                   2903820
# Arkansas                 2977944
# Mississippi              2986220
# Utah                     2993941
# Iowa                     3118102
# Puerto Rico              3468963
# Connecticut              3594478
# Oklahoma                 3896251
# Oregon                   4025127
# Kentucky                 4424376
# Louisiana                4663461
# Alabama                  4850771
# South Carolina           4893444
# Colorado                 5436519
# Minnesota                5490726
# Wisconsin                5763217
# Maryland                 5996079
# Missouri                 6075300
# Tennessee                6597381
# Indiana                  6614418
# Massachusetts            6789319
# Arizona                  6809946
# Washington               7169967
# Virginia                 8365952
# New Jersey               8960161
# Michigan                 9925568
# North Carolina          10052564
# Georgia                 10201635
# Ohio                    11609756
# Pennsylvania            12790505
# Illinois                12854526
# New York                19798228
# Florida                 20278447
# Texas                   27419612
# California              38982847
# Name: TotalPop, dtype: int64

# %% [markdown]
# ### Q8 (b). Select the state with the most population and save the dataframe as `df_largest`. (0.5pt)
#
# Hint: Use ```df.loc[]``` and select the rows where ```State``` is the one you found in Q4.

# %%
df_largest = df.loc[df['State'] == 'California']
df_largest
# Out:
#                State                  County  ...  OtherTransp  WorkAtHome
# CountyId                                      ...
# 6001      California          Alameda County  ...          3.6         6.0
# 6003      California           Alpine County  ...          1.6        14.0
# 6005      California           Amador County  ...          1.1         6.4
# 6007      California            Butte County  ...          3.9         5.7
# 6009      California        Calaveras County  ...          0.6         8.3
# 6011      California           Colusa County  ...          1.6         4.5
# 6013      California     Contra Costa County  ...          1.9         6.3
# 6015      California        Del Norte County  ...          1.9         5.6
# 6017      California        El Dorado County  ...          1.6         8.3
# 6019      California           Fresno County  ...          2.5         4.3
# 6021      California            Glenn County  ...          1.6         5.7
# 6023      California         Humboldt County  ...          2.8         7.4
# 6025      California         Imperial County  ...          2.6         4.4
# 6027      California             Inyo County  ...          5.2         4.5
# 6029      California             Kern County  ...          2.7         3.2
# 6031      California            Kings County  ...          2.0         5.0
# 6033      California             Lake County  ...          0.6        12.5
# 6035      California           Lassen County  ...          0.9         5.8
# 6037      California      Los Angeles County  ...          2.3         5.3
# 6039      California           Madera County  ...          2.0         3.6
# 6041      California            Marin County  ...          2.4        10.7
# 6043      California         Mariposa County  ...          3.9         9.2
# 6045      California        Mendocino County  ...          1.7         8.1
# 6047      California           Merced County  ...          3.7         3.4
# 6049      California            Modoc County  ...          0.7        15.1
# 6051      California             Mono County  ...          8.1         9.3
# 6053      California         Monterey County  ...          8.8         4.6
# 6055      California             Napa County  ...          1.6         5.6
# 6057      California           Nevada County  ...          2.7        10.4
# 6059      California           Orange County  ...          2.0         5.6
# 6061      California           Placer County  ...          1.6         8.3
# 6063      California           Plumas County  ...          2.3         5.7
# 6065      California        Riverside County  ...          1.7         5.2
# 6067      California       Sacramento County  ...          2.4         5.5
# 6069      California       San Benito County  ...          1.1         3.4
# 6071      California   San Bernardino County  ...          1.2         4.7
# 6073      California        San Diego County  ...          2.2         7.0
# 6075      California    San Francisco County  ...          7.1         6.7
# 6077      California      San Joaquin County  ...          1.5         4.0
# 6079      California  San Luis Obispo County  ...          3.2         6.7
# 6081      California        San Mateo County  ...          2.8         4.8
# 6083      California    Santa Barbara County  ...          4.8         5.8
# 6085      California      Santa Clara County  ...          3.1         4.8
# 6087      California       Santa Cruz County  ...          7.0         7.5
# 6089      California           Shasta County  ...          1.9         5.8
# 6091      California           Sierra County  ...          0.7        18.1
# 6093      California         Siskiyou County  ...          1.3         8.9
# 6095      California           Solano County  ...          1.4         4.1
# 6097      California           Sonoma County  ...          2.1         6.9
# 6099      California       Stanislaus County  ...          1.7         4.6
# 6101      California           Sutter County  ...          1.4         4.6
# 6103      California           Tehama County  ...          1.5         4.7
# 6105      California          Trinity County  ...          2.2        15.1
# 6107      California           Tulare County  ...          2.2         3.1
# 6109      California         Tuolumne County  ...          1.7         6.5
# 6111      California          Ventura County  ...          1.5         5.7
# 6113      California             Yolo County  ...          9.4         5.0
# 6115      California             Yuba County  ...          1.4         4.8
#
# [58 rows x 12 columns]

# %% [markdown]
# ### Q9 (a). Find out the average income of the state with the largest population `df_largest`. (0.5pt)

# %%
df_largest['Income'].mean()
# Out:
# 61046.75862068965

# %% [markdown]
# ### Q9 (b). Select the counties where their income is greater than $60,000 in `df_largest` and save the dataframe as `high_income`. (0.5pt)

# %%
filter = df_largest['Income'] > 60000
high_income = df_largest.loc[filter]
high_income
# Out:
#                State                  County  ...  OtherTransp  WorkAtHome
# CountyId                                      ...
# 6001      California          Alameda County  ...          3.6         6.0
# 6003      California           Alpine County  ...          1.6        14.0
# 6005      California           Amador County  ...          1.1         6.4
# 6013      California     Contra Costa County  ...          1.9         6.3
# 6017      California        El Dorado County  ...          1.6         8.3
# 6037      California      Los Angeles County  ...          2.3         5.3
# 6041      California            Marin County  ...          2.4        10.7
# 6051      California             Mono County  ...          8.1         9.3
# 6053      California         Monterey County  ...          8.8         4.6
# 6055      California             Napa County  ...          1.6         5.6
# 6057      California           Nevada County  ...          2.7        10.4
# 6059      California           Orange County  ...          2.0         5.6
# 6061      California           Placer County  ...          1.6         8.3
# 6065      California        Riverside County  ...          1.7         5.2
# 6067      California       Sacramento County  ...          2.4         5.5
# 6069      California       San Benito County  ...          1.1         3.4
# 6073      California        San Diego County  ...          2.2         7.0
# 6075      California    San Francisco County  ...          7.1         6.7
# 6079      California  San Luis Obispo County  ...          3.2         6.7
# 6081      California        San Mateo County  ...          2.8         4.8
# 6083      California    Santa Barbara County  ...          4.8         5.8
# 6085      California      Santa Clara County  ...          3.1         4.8
# 6087      California       Santa Cruz County  ...          7.0         7.5
# 6095      California           Solano County  ...          1.4         4.1
# 6097      California           Sonoma County  ...          2.1         6.9
# 6111      California          Ventura County  ...          1.5         5.7
# 6113      California             Yolo County  ...          9.4         5.0
#
# [27 rows x 12 columns]

# %% [markdown]
# ### Q10. Find out top 2 most popular means of transportation to work in ```high_income```. (1pt)
#
# Hint: Use the following columns: 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome' and an AGGREGATE function.

# %% [markdown]
# #### Code:

# %%
high_income[['Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome']].sum()
# Out:
# Drive          1911.7
# Carpool         279.4
# Transit         144.3
# Walk             95.6
# OtherTransp      89.1
# WorkAtHome      179.9
# dtype: float64

# %% [markdown]
# #### Answer: type your answer in a string form.

# %%
'Drive and Carpool'
# Out:
# 'Drive and Carpool'
