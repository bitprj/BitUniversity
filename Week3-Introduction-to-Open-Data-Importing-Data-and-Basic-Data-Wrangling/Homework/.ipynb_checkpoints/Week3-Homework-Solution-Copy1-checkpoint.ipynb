# %% [markdown]
# ## <div align = "center">Homework 3</div>
# # <div align = "center">US Census Data</div>

# %% [markdown]
# **Welcome to Homework 3!** In this homework you will be using techniques you learned in Week 3. The purpose of this homework for you to do data manipulation with ```Pandas``` and to express your observations.
#
# Feel free to refer back to week 3 tutorial notebook and ask questions on Piazza!

# %% [markdown]
# ### Grading

# %% [markdown]
# There are a total of five questions and each question is worth 3-5 points.

# %% [markdown]
# ### Import Library

# %%
import pandas as pd

# %% [markdown]
# ### Load dataset

# %%
url = 'https://raw.githubusercontent.com/bitprj/DigitalHistory/master/Week3-Introduction-to-Open-Data-Importing-Data-and-Basic-Data-Wrangling/data/acs2017_county_data.csv'
df = pd.read_csv(url)
df
# Out:
#       CountyId        State               County  TotalPop    Men   Women  \
# 0         1001      Alabama       Autauga County     55036  26899   28137
# 1         1003      Alabama       Baldwin County    203360  99527  103833
# 2         1005      Alabama       Barbour County     26201  13976   12225
# 3         1007      Alabama          Bibb County     22580  12251   10329
# 4         1009      Alabama        Blount County     57667  28490   29177
# ...        ...          ...                  ...       ...    ...     ...
# 3215     72145  Puerto Rico  Vega Baja Municipio     54754  26269   28485
# 3216     72147  Puerto Rico    Vieques Municipio      8931   4351    4580
# 3217     72149  Puerto Rico   Villalba Municipio     23659  11510   12149
# 3218     72151  Puerto Rico    Yabucoa Municipio     35025  16984   18041
# 3219     72153  Puerto Rico      Yauco Municipio     37585  18052   19533
#
#       Hispanic  White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  \
# ...

# %% [markdown]
# ## Homework Questions
#
# **Since this dataset has lots of information, feel free to select a set of columns to answer each question.**

# %%
df.head()
# Out:
#    CountyId    State          County  TotalPop    Men   Women  Hispanic  \
# 0      1001  Alabama  Autauga County     55036  26899   28137       2.7
# 1      1003  Alabama  Baldwin County    203360  99527  103833       4.4
# 2      1005  Alabama  Barbour County     26201  13976   12225       4.2
# 3      1007  Alabama     Bibb County     22580  12251   10329       2.4
# 4      1009  Alabama   Blount County     57667  28490   29177       9.0
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   75.4   18.9     0.3  ...   0.6          1.3         2.5         25.8
# 1   83.1    9.5     0.8  ...   0.8          1.1         5.6         27.0
# 2   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 3   74.6   22.0     0.4  ...   0.3          1.7         1.5         30.0
# 4   87.4    1.5     0.3  ...   0.4          0.4         2.1         35.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %% [markdown]
# ### Q1. List out all column names of ```df```.

# %% [markdown]
# #### Answer:

# %%
df.columns
# Out:
# Index(['CountyId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %% [markdown]
# ### Q2. Set ```CountyId``` as an index for ```df```.

# %%
df.set_index(keys='CountyId', inplace=True)

# %%
df
# Out:
#                 State               County  TotalPop    Men   Women  Hispanic  \
# CountyId
# 1001          Alabama       Autauga County     55036  26899   28137       2.7
# 1003          Alabama       Baldwin County    203360  99527  103833       4.4
# 1005          Alabama       Barbour County     26201  13976   12225       4.2
# 1007          Alabama          Bibb County     22580  12251   10329       2.4
# 1009          Alabama        Blount County     57667  28490   29177       9.0
# ...               ...                  ...       ...    ...     ...       ...
# 72145     Puerto Rico  Vega Baja Municipio     54754  26269   28485      96.7
# 72147     Puerto Rico    Vieques Municipio      8931   4351    4580      95.7
# 72149     Puerto Rico   Villalba Municipio     23659  11510   12149      99.7
# 72151     Puerto Rico    Yabucoa Municipio     35025  16984   18041      99.9
# 72153     Puerto Rico      Yauco Municipio     37585  18052   19533      99.8
#
# ...

# %% [markdown]
# ### Q3 (a) Find the rows where ```Unemployment``` is greater than 10.

# %%
df.loc[df['Unemployment'] > 10]
# Out:
#                 State               County  TotalPop    Men  Women  Hispanic  \
# CountyId
# 1005          Alabama       Barbour County     26201  13976  12225       4.2
# 1011          Alabama       Bullock County     10478   5616   4862       0.3
# 1015          Alabama       Calhoun County    115527  55593  59934       3.6
# 1025          Alabama        Clarke County     24625  11649  12976       0.2
# 1035          Alabama       Conecuh County     12649   6040   6609       1.8
# ...               ...                  ...       ...    ...    ...       ...
# 72145     Puerto Rico  Vega Baja Municipio     54754  26269  28485      96.7
# 72147     Puerto Rico    Vieques Municipio      8931   4351   4580      95.7
# 72149     Puerto Rico   Villalba Municipio     23659  11510  12149      99.7
# 72151     Puerto Rico    Yabucoa Municipio     35025  16984  18041      99.9
# 72153     Puerto Rico      Yauco Municipio     37585  18052  19533      99.8
#
# ...

# %% [markdown]
# ### Q3 (b) How many counties have ```Unemployment``` > 10?

# %% [markdown]
# #### Answer:

# %%
# type your answer here
346

# %% [markdown]
# ### Q4. Find the state with most self-employeed population.

# %%
# write your code here
df.groupby(['State'])['SelfEmployed'].sum().sort_values(ascending=False)
# Out:
# State
# Texas                   2268.2
# Nebraska                1213.6
# Kansas                  1075.8
# Georgia                  972.5
# Missouri                 959.7
# South Dakota             918.1
# Iowa                     890.7
# North Dakota             789.0
# Kentucky                 781.6
# Tennessee                759.7
# Virginia                 740.3
# Montana                  738.4
# Minnesota                702.6
# North Carolina           669.7
# Illinois                 667.0
# Puerto Rico              652.2
# Colorado                 639.0
# Oklahoma                 619.6
# California               554.9
# Arkansas                 553.2
# Michigan                 536.6
# Wisconsin                511.6
# Indiana                  486.2
# Ohio                     486.1
# Mississippi              475.7
# Florida                  422.0
# Pennsylvania             402.3
# New York                 402.1
# Idaho                    386.5
# Alabama                  373.4
# ...

# %% [markdown]
# #### Answer:

# %%
# type your answer here
Texas

# %% [markdown]
# ### Q5 (a) Select the state with most self-employed population and save the dataframe as ```df_self_emp```.

# %%
df_self_emp = df.loc[df['State']=='Texas']

# %% [markdown]
# ### Q5 (b) Find out top 2 most popular means of transportation to work in ```df_self_emp```.

# %%
df_self_emp[['Drive','Carpool','Transit','Walk','OtherTransp','WorkAtHome']].sum()
# Out:
# Drive          20455.0
# Carpool         2888.5
# Transit           79.4
# Walk             600.6
# OtherTransp      363.2
# WorkAtHome      1013.9
# dtype: float64

# %% [markdown]
# #### Answer:

# %%
Drive, carpool

# %% [markdown]
# ### Q6. What are the top 3 states with highest ```mean commute```?

# %%
df.groupby(['State'])['MeanCommute'].sum().sort_values(ascending=False)
# Out:
# State
# Texas                   5825.3
# Georgia                 4119.7
# Virginia                3676.2
# Kentucky                3048.9
# Missouri                2721.9
# Tennessee               2519.0
# North Carolina          2518.8
# Illinois                2402.2
# Indiana                 2241.1
# Puerto Rico             2207.0
# Ohio                    2153.8
# Mississippi             2151.6
# Iowa                    1936.4
# Michigan                1918.0
# Minnesota               1860.6
# Kansas                  1860.4
# Florida                 1768.2
# Alabama                 1754.7
# Arkansas                1726.0
# Pennsylvania            1701.8
# Louisiana               1697.7
# Nebraska                1681.4
# Oklahoma                1678.1
# Wisconsin               1608.7
# New York                1594.5
# West Virginia           1546.6
# California              1480.6
# Colorado                1386.6
# South Carolina          1198.8
# South Dakota            1119.8
# ...

# %% [markdown]
# #### Answer

# %%
Texas, Georgia, Virginia

# %% [markdown]
# ### Q7 (a) Select the subset of data where ```State``` is one of the states we found in question 6 and save it as top_three.

# %%
top_three = df.loc[df['State'].isin(['Texas','Georgia','Virginia'])]

# %% [markdown]
# ### Q7 (b) How many counties are there in the top three states? Hint: use one of the aggregate functions.

# %%
top_three['County'].count()

# alternatively, top_three.shape[0]
# Out:
# 546

# %% [markdown]
# ### Q7 (c) Find the County with the most ```MeanCommute``` time in ```top_three```.

# %%
top_three.sort_values(by='MeanCommute')
# Out:
#              State               County  TotalPop    Men  Women  Hispanic  \
# CountyId
# 48263        Texas          Kent County       680    311    369      21.6
# 48023        Texas        Baylor County      3602   1740   1862      10.1
# 48487        Texas     Wilbarger County     12972   6415   6557      28.6
# 48205        Texas       Hartley County      5821   3524   2297      26.2
# 48269        Texas          King County       289    150    139      26.6
# ...            ...                  ...       ...    ...    ...       ...
# 51049     Virginia    Cumberland County      9797   4830   4967       0.1
# 51187     Virginia        Warren County     38991  19445  19546       4.2
# 51179     Virginia      Stafford County    141159  70984  70175      11.7
# 48407        Texas   San Jacinto County     27436  13563  13873      12.5
# 51193     Virginia  Westmoreland County     17596   8646   8950       6.2
#
# ...

# %% [markdown]
# #### Answer:

# %%
Westmoreland County

# %% [markdown]
# ### Q8. Find the top 5 states with highest income level and find out their top professional working field: 'Professional', 'Service', 'Office', 'Construction', or 'Production.'
#
# (hint: use the same approach as Q6 and Q7.)

# %%
df.groupby(['State'])['Income'].sum().sort_values(ascending=False)
# Out:
# State
# Texas                   12673162
# Virginia                 7483915
# Georgia                  6879737
# Illinois                 5398899
# Iowa                     5290172
# Kansas                   5252370
# Missouri                 5110060
# Minnesota                5005110
# Kentucky                 4976459
# Nebraska                 4829337
# Indiana                  4772721
# Ohio                     4553314
# North Carolina           4455167
# Tennessee                4086578
# Michigan                 3945033
# Wisconsin                3877158
# New York                 3615174
# Pennsylvania             3569886
# Oklahoma                 3558929
# California               3540712
# Colorado                 3478628
# South Dakota             3326977
# North Dakota             3169186
# Florida                  3158670
# Mississippi              3035535
# Arkansas                 2926881
# Louisiana                2729861
# Alabama                  2698184
# ...

# %%
top_five = df.loc[df['State'].isin(['Texas','Virginia','Georgia','Illinois','Iowa'])]
top_five
# Out:
#              State               County  TotalPop     Men   Women  Hispanic  \
# CountyId
# 13001      Georgia       Appling County     18471    9090    9381       9.7
# 13003      Georgia      Atkinson County      8313    4112    4201      24.6
# 13005      Georgia         Bacon County     11279    5599    5680       8.5
# 13007      Georgia         Baker County      3251    1547    1704       5.4
# 13009      Georgia       Baldwin County     45527   22893   22634       2.2
# ...            ...                  ...       ...     ...     ...       ...
# 51800     Virginia         Suffolk city     88057   42594   45463       4.0
# 51810     Virginia  Virginia Beach city    450057  221350  228707       7.8
# 51820     Virginia      Waynesboro city     21620   10438   11182       7.2
# 51830     Virginia    Williamsburg city     14817    6829    7988       7.7
# 51840     Virginia      Winchester city     27516   13444   14072      16.9
#
# ...

# %%
top_five[['Professional', 'Service', 'Office', 'Construction', 'Production']].sum()
# Out:
# Professional    22994.0
# Service         13431.9
# Office          16506.8
# Construction     9718.9
# Production      12050.7
# dtype: float64

# %% [markdown]
# #### What are the top five states with highest income?

# %%
# write your answer here.
Texas, Virginia, Georgia, Illinois, Iowa

# %% [markdown]
# #### What is the most popular working field in the top five states?

# %%
# write your answer here.
Professional

# %% [markdown]
# ### Q9. Find the state with highest male population.

# %%
# write your code here
df.groupby(['State'])['Men'].sum().sort_values(ascending=False)
# Out:
# State
# California              19366579
# Texas                   13616977
# Florida                  9914361
# New York                 9604111
# Illinois                 6312600
# Pennsylvania             6260160
# Ohio                     5686081
# Georgia                  4968887
# North Carolina           4895368
# Michigan                 4880579
# New Jersey               4372321
# Virginia                 4113988
# Washington               3580888
# Arizona                  3385055
# Massachusetts            3293426
# Indiana                  3258279
# Tennessee                3217073
# Missouri                 2981332
# Maryland                 2906277
# Wisconsin                2864115
# Minnesota                2731831
# Colorado                 2731315
# South Carolina           2376759
# Alabama                  2350806
# Louisiana                2281239
# Kentucky                 2179025
# Oregon                   1993822
# Oklahoma                 1930615
# ...

# %% [markdown]
# #### Answer:

# %%
# type your answer here
California

# %% [markdown]
# ### Q10. Select the state where male population is greater than female population.
# (Hint 1: Find the sum of male and female population at a state level.)
#
# (Hint 2: There are 10 states that meet this condition.)

# %%
total_pop = df.groupby(['State'])['Men','Women'].sum()

# %%
total_pop.loc[total_pop['Men'] > total_pop['Women']]
# Out:
#                   Men    Women
# State
# Alaska         386319   352246
# Colorado      2731315  2705204
# Hawaii         713981   707677
# Idaho          830627   826748
# Montana        517860   512002
# Nevada        1450091  1437634
# North Dakota   382121   363354
# South Dakota   430587   424857
# Utah          1506614  1487327
# Wyoming        298301   284899

# %%
# type your answer here.
Alaska, Colorado, Hawaii, Idaho, Montana, Nevada, North Dakota, South Dakota, Utah, Wyoming
