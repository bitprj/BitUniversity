# %% [markdown]
# ## <div align = "center">Homework 4</div>
# # <div align = "center">Malnutrition, A disease the world has forgotten</div>

# %%
# !pip install descartes
# !pip install geopandas

# %% [markdown]
# Welcome to Homework 4, In this homework you will be using techniques you learned throughout Week 4. The purpose of this homework for you to be able to use the visualization methods and be able to express your observations in a written form. You will be asked to find answers to questions using ```matplotlib``` and ```pandas```. Because these topics are very new to you and can be challenging to absorb, we will be giving you hints for some coding questions or references to sections in the week 4 tutorial notebook.
#
# By the end of the extercise the deliverables are:
#
# |    Questions                                      | # of assignments|
# |---------------------------------------------------|-----------------|
# |Dataframe cleaning using pandas                    |1                |
# |Pandas Questions                                   |4                |
# |Histogram plots                                    |1                |
# |Scatter plots                                      |4                |
# |Bar plots                                          |4                |
# |Plot of the world map with the required features.  |3                |
# |A comparision between two countries of your choice |3                |

# %% [markdown]
# ## About the Dataset
#
# ### Malnutrition EDA
# Malnutrition is a condition that results from eating a diet in which one or more nutrients are either not enough or are too much such that the diet causes health problems.
#
# Wasting : Also known as 'acute malnutrition', wasting is characterised by a rapid deterioration in nutritional status over a short period of time in children under five years of age. Wasted children are at higher risk of dying.
#
# Stunting is the impaired growth and development that children experience from poor nutrition, repeated infection, and inadequate psychosocial stimulation. Children are defined as stunted if their height-for-age is more than two standard deviations below the WHO Child Growth Standards median.
#
# **The data available**
#
# ```Severe Wasting``` - % of children aged 0–59 months who are below minus three standard deviations from median weight-for-height.
#
# ```Wasting``` – Moderate and severe: % of children aged 0–59 months who are below minus two standard deviations from median weight-for-height
#
# ```Overweight``` – Moderate and severe: % aged 0-59 months who are above two standard deviations from median weight-for-height
#
# ```Stunting``` – Moderate and severe:
# % of children aged 0–59 months who are below minus two standard deviations from median height-for-age
#
# ```Underweight``` – Moderate and severe: % of children aged 0–59 months who are below minus two standard deviations from median weight-for-age
#
# ```Income Classification``` - When it comes to income , the World Bank divides the world's economies into four income groups:
# - High
# - Upper-middle
# - Lower-middle
# - Low
#
# The income classification is based on a measure of national income per person, or GNI per capita, calculated using the Atlas method

# %% [markdown]
# ## Grading
#
# Ever question in this homework is worth a point, There are a total of 20 questions.
# If a question has 2 parts, each are worth half a point

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset

# %%
df = pd.read_csv('../malnutrition/malnutrition.csv')
df
# Out:
#      Unnamed: 0                             Country  Income Classification  \
# 0             0                         AFGHANISTAN                    0.0
# 1             1                             ALBANIA                    2.0
# 2             2                             ALGERIA                    2.0
# 3             3                              ANGOLA                    1.0
# 4             4                           ARGENTINA                    2.0
# ..          ...                                 ...                    ...
# 147         147  VENEZUELA (BOLIVARIAN REPUBLIC OF)                    2.0
# 148         148                            VIET NAM                    1.0
# 149         149                               YEMEN                    0.0
# 150         150                              ZAMBIA                    1.0
# 151         151                            ZIMBABWE                    1.0
#
#      Severe Wasting    Wasting  Overweight   Stunting  Underweight  \
# 0          3.033333  10.350000    5.125000  47.775000    30.375000
# 1          4.075000   7.760000   20.800000  24.160000     7.700000
# 2          2.733333   5.942857   12.833333  19.571429     7.342857
# 3          2.400000   6.933333    2.550000  42.633333    23.600000
# 4          0.200000   2.150000   11.125000  10.025000     2.600000
# ..              ...        ...         ...        ...          ...
# 147             NaN   4.333333    5.409524  16.957143     4.242857
# 148        2.331250   8.661905    3.317647  34.922727    22.918182
# 149        5.300000  15.242857    4.842857  51.900000    37.785714
# 150        2.042857   5.542857    7.228571  48.137500    17.885714
# 151        1.388889   4.166667    5.788889  30.455556    10.710000
#
#      U5 Population ('000s)   Longitude   Latitude
# 0              4918.561500   66.238514  33.768006
# 1               232.859800   19.999962  41.000028
# 2              3565.213143    2.999983  28.000027
# 3              3980.054000   17.569124 -11.877577
# 4              3613.651750  -64.967282 -34.996496
# ..                     ...         ...        ...
# 147            2787.800095  -66.110932   8.001871
# 148            7507.220273  108.426511  13.290403
# 149            3269.476000   47.891527  16.347124
# 150            2083.494500   27.559916 -14.518624
# 151            1912.450400   29.746841 -18.455496
#
# [152 rows x 11 columns]

# %%
df = df.drop(columns = 'Unnamed: 0',axis = 1)
df
# Out:
#                                 Country  Income Classification  \
# 0                           AFGHANISTAN                    0.0
# 1                               ALBANIA                    2.0
# 2                               ALGERIA                    2.0
# 3                                ANGOLA                    1.0
# 4                             ARGENTINA                    2.0
# ..                                  ...                    ...
# 147  VENEZUELA (BOLIVARIAN REPUBLIC OF)                    2.0
# 148                            VIET NAM                    1.0
# 149                               YEMEN                    0.0
# 150                              ZAMBIA                    1.0
# 151                            ZIMBABWE                    1.0
#
#      Severe Wasting    Wasting  Overweight   Stunting  Underweight  \
# 0          3.033333  10.350000    5.125000  47.775000    30.375000
# 1          4.075000   7.760000   20.800000  24.160000     7.700000
# 2          2.733333   5.942857   12.833333  19.571429     7.342857
# 3          2.400000   6.933333    2.550000  42.633333    23.600000
# 4          0.200000   2.150000   11.125000  10.025000     2.600000
# ..              ...        ...         ...        ...          ...
# 147             NaN   4.333333    5.409524  16.957143     4.242857
# 148        2.331250   8.661905    3.317647  34.922727    22.918182
# 149        5.300000  15.242857    4.842857  51.900000    37.785714
# 150        2.042857   5.542857    7.228571  48.137500    17.885714
# 151        1.388889   4.166667    5.788889  30.455556    10.710000
#
#      U5 Population ('000s)   Longitude   Latitude
# 0              4918.561500   66.238514  33.768006
# 1               232.859800   19.999962  41.000028
# 2              3565.213143    2.999983  28.000027
# 3              3980.054000   17.569124 -11.877577
# 4              3613.651750  -64.967282 -34.996496
# ..                     ...         ...        ...
# 147            2787.800095  -66.110932   8.001871
# 148            7507.220273  108.426511  13.290403
# 149            3269.476000   47.891527  16.347124
# 150            2083.494500   27.559916 -14.518624
# 151            1912.450400   29.746841 -18.455496
#
# [152 rows x 10 columns]

# %% [markdown]
# ## Use pandas to display the basic information of the dataset

# %%
df.head()
# Out:
#        Country  Income Classification  Severe Wasting    Wasting  Overweight  \
# 0  AFGHANISTAN                    0.0        3.033333  10.350000    5.125000
# 1      ALBANIA                    2.0        4.075000   7.760000   20.800000
# 2      ALGERIA                    2.0        2.733333   5.942857   12.833333
# 3       ANGOLA                    1.0        2.400000   6.933333    2.550000
# 4    ARGENTINA                    2.0        0.200000   2.150000   11.125000
#
#     Stunting  Underweight  U5 Population ('000s)  Longitude   Latitude
# 0  47.775000    30.375000            4918.561500  66.238514  33.768006
# 1  24.160000     7.700000             232.859800  19.999962  41.000028
# 2  19.571429     7.342857            3565.213143   2.999983  28.000027
# 3  42.633333    23.600000            3980.054000  17.569124 -11.877577
# 4  10.025000     2.600000            3613.651750 -64.967282 -34.996496

# %%
df.tail()
# Out:
#                                 Country  Income Classification  \
# 147  VENEZUELA (BOLIVARIAN REPUBLIC OF)                    2.0
# 148                            VIET NAM                    1.0
# 149                               YEMEN                    0.0
# 150                              ZAMBIA                    1.0
# 151                            ZIMBABWE                    1.0
#
#      Severe Wasting    Wasting  Overweight   Stunting  Underweight  \
# 147             NaN   4.333333    5.409524  16.957143     4.242857
# 148        2.331250   8.661905    3.317647  34.922727    22.918182
# 149        5.300000  15.242857    4.842857  51.900000    37.785714
# 150        2.042857   5.542857    7.228571  48.137500    17.885714
# 151        1.388889   4.166667    5.788889  30.455556    10.710000
#
#      U5 Population ('000s)   Longitude   Latitude
# 147            2787.800095  -66.110932   8.001871
# 148            7507.220273  108.426511  13.290403
# 149            3269.476000   47.891527  16.347124
# 150            2083.494500   27.559916 -14.518624
# 151            1912.450400   29.746841 -18.455496

# %%
df.describe()
# Out:
#        Income Classification  Severe Wasting     Wasting  Overweight  \
# count             152.000000      140.000000  150.000000  149.000000
# mean                1.427632        2.168650    6.599257    7.201638
# std                 0.967019        1.708939    4.481723    4.649144
# min                 0.000000        0.000000    0.000000    0.962500
# 25%                 1.000000        0.900000    3.262500    3.850000
# 50%                 1.000000        1.872500    5.710714    6.300000
# 75%                 2.000000        2.822727    8.740476    9.080000
# max                 3.000000       11.400000   23.650000   26.500000
#
#          Stunting  Underweight  U5 Population ('000s)   Longitude    Latitude
# count  151.000000   150.000000             152.000000  149.000000  149.000000
# mean    25.814728    13.503047            4042.927052   22.035323   13.137684
# std     14.686807    10.895839           13164.191927   70.385056   21.539540
# min      1.000000     0.100000               1.000000 -175.202642  -34.996496
# 25%     13.485000     4.305000             241.765813  -10.708359   -0.525231
# 50%     24.160000    10.380000             981.233486   27.697136   13.150033
# 75%     36.564935    19.496875            3002.433080   57.003690   30.330840
# max     57.600000    46.266667          123014.491000  179.158292   61.066692

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 10 columns):
# Country                  152 non-null object
# Income Classification    152 non-null float64
# Severe Wasting           140 non-null float64
# Wasting                  150 non-null float64
# Overweight               149 non-null float64
# Stunting                 151 non-null float64
# Underweight              150 non-null float64
# U5 Population ('000s)    152 non-null float64
# Longitude                149 non-null float64
# Latitude                 149 non-null float64
# dtypes: float64(9), object(1)
# memory usage: 12.0+ KB

# %% [markdown]
# ### Q1. Check the total number of null values for each column and drop them [Graded]

# %%
df.isnull().sum()
# Out:
# Country                   0
# Income Classification     0
# Severe Wasting           12
# Wasting                   2
# Overweight                3
# Stunting                  1
# Underweight               2
# U5 Population ('000s)     0
# Longitude                 3
# Latitude                  3
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#          Country  Income Classification  Severe Wasting    Wasting  \
# 0    AFGHANISTAN                    0.0        3.033333  10.350000
# 1        ALBANIA                    2.0        4.075000   7.760000
# 2        ALGERIA                    2.0        2.733333   5.942857
# 3         ANGOLA                    1.0        2.400000   6.933333
# 4      ARGENTINA                    2.0        0.200000   2.150000
# ..           ...                    ...             ...        ...
# 146      VANUATU                    1.0        1.700000   5.800000
# 148     VIET NAM                    1.0        2.331250   8.661905
# 149        YEMEN                    0.0        5.300000  15.242857
# 150       ZAMBIA                    1.0        2.042857   5.542857
# 151     ZIMBABWE                    1.0        1.388889   4.166667
#
#      Overweight   Stunting  Underweight  U5 Population ('000s)   Longitude  \
# 0      5.125000  47.775000    30.375000            4918.561500   66.238514
# 1     20.800000  24.160000     7.700000             232.859800   19.999962
# 2     12.833333  19.571429     7.342857            3565.213143    2.999983
# 3      2.550000  42.633333    23.600000            3980.054000   17.569124
# 4     11.125000  10.025000     2.600000            3613.651750  -64.967282
# ..          ...        ...          ...                    ...         ...
# 146    4.800000  26.766667    11.266667              31.771333  168.106915
# 148    3.317647  34.922727    22.918182            7507.220273  108.426511
# 149    4.842857  51.900000    37.785714            3269.476000   47.891527
# 150    7.228571  48.137500    17.885714            2083.494500   27.559916
# 151    5.788889  30.455556    10.710000            1912.450400   29.746841
#
#       Latitude
# 0    33.768006
# 1    41.000028
# 2    28.000027
# 3   -11.877577
# 4   -34.996496
# ..         ...
# 146 -16.525507
# 148  13.290403
# 149  16.347124
# 150 -14.518624
# 151 -18.455496
#
# [137 rows x 10 columns]

# %% [markdown]
# ## Pandas Questions

# %% [markdown]
# *Hint: Use Pandas*

# %% [markdown]
# ### Q2. Which country shows highest Underweight percentage? [Graded]

# %% [markdown]
# ### Q3. Which country shows highest Overweight percentage? [Graded]

# %% [markdown]
# ### Q4. Top 5 Countries that are the most malnourished? [Graded]

# %% [markdown]
# ### Q5. Top 5 Countries that are the most malnourished? [Graded]

# %% [markdown]
# ## Histograms

# %% [markdown]
# ### Q6. Unique Income Classification Histogram [Graded]

# %%
# Check the number of Unique values int the 'Income Classification' column
df['Income Classification'].unique()
# Out:
# array([0., 2., 1., 3.])

# %%
# Display the histogram for the Income Classification column, set bins to 20
df["Income Classification"].hist(bins = 20)

# %% [markdown]
# ### Scatter Plots for Income Classification
#
# In this part you will be drawing four scatterplots as subplots of a larger plot. The plot will have a figure size of (20,10)

# %%
fig = plt.figure(figsize = (30,15))

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %% [markdown]
# ### Q7. Wasting [Graded]

# %%
df.plot(kind = 'scatter',
        x = 'Income Classification',
        y='Wasting',ax = ax1,color='k')
# Out:
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# ### Q8. Overweight [Graded]

# %%
df.plot(kind = 'scatter',
        x = 'Income Classification',
        y='Overweight',ax = ax2,color='r')

# %% [markdown]
# ### Q9. Stunting [Graded]

# %%
df.plot(kind = 'scatter',
        x = 'Income Classification',
        y='Stunting',ax = ax3,color='g')

# %% [markdown]
# ### Q10. U5 Population (\'000s) [Graded]

# %%
df.plot(kind = 'scatter',
        x = 'Income Classification',
        y='U5 Population (\'000s)',ax = ax4)

# %%
fig

# %% [markdown]
# ## Bar Graphs

# %% [markdown]
# ### Q11. Plot a bar graph for the countries that have a waste percentage greater or equal to 15 [GRADED]

# %%
filt = df['Wasting'] >= 15

max_waste = df.where(filt)
max_waste = max_waste.dropna()
max_waste
max_waste.plot(kind = 'bar',x = 'Country',y='Wasting')

# %% [markdown]
# ### Q12. Plot a bar graph for the countries that have a waste percentage less than or equal to 2 [GRADED]

# %%
filt = df['Wasting'] <= 2

low_waste = df.where(filt)
low_waste = low_waste.dropna()
low_waste.plot(kind = 'bar',x = 'Country',y='Wasting')

# %% [markdown]
# ### Q13. Plot a bar graph showing all the countries with an income classification of 3.0

# %%
filt = df['Income Classification'] == 3.0

HIGH_Income = df.where(filt)
HIGH_Income = HIGH_Income.dropna()
HIGH_Income.plot(kind = 'bar',x = 'Country',y='Stunting',figsize=(20,10))

# %% [markdown]
# ### Q14. Plot a bar graph showing all the countries with an Income Classification of 0 [GRADED]

# %%
filt = df['Income Classification'] == 0.0

LOW_Income = df.where(filt)
LOW_Income = LOW_Income.dropna()
LOW_Income.plot(kind = 'bar',x = 'Country',y='Stunting',figsize = (20,10))

# %% [markdown]
# ## Plot the World Map

# %%
import descartes
import geopandas as gpd
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# ### 15. Plot the Longitude vs Latitude [GRADED]

# %%
fig,ax = plt.subplots(figsize=(30,15))
world.plot(ax=ax, color='lightgray')

df.plot(kind="scatter",
        x="Longitude",
        y="Latitude",
        alpha = 0.6,
        figsize=(20,10),
        ax = ax)

plt.show()

# %% [markdown]
# ### 16. Adding a color map for Income Classification [GRADED]
#
# Property : ```c : color, sequence, or sequence of color```
#
# Equate it to Income Classification.
#
# Also add the following:
# - ```cmap : Colormap```
# - ```colorbar```
# - ```xlabel```
# - ```ylabel```
# - ```legend```
#
# **Note**: Features in the plot above must be present.

# %%
fig, ax = plt.subplots(figsize=(20,10))
world.plot(ax=ax, color='lightgray')
df.plot(kind="scatter",
             x="Longitude",
             y="Latitude",
             alpha=0.4,
             c="Income Classification", 
             cmap=plt.get_cmap("jet"),
             colorbar=True,
             ax = ax)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()
# Out:
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# No handles with labels found to put in legend.

# %% [markdown]
# ### 17. Adding a scalar pointer, U5-population
# Property: ```s : scalar or array_like, shape (n, )```
#
#
# Also add the following:
# - Replace c with Stunting
# - Add a label for the feature
#
# **Note:** In order to get a viewable graph you will have to divide the feature by a multiple of 10. Be careful, too high and your scalar points won't be distinguishable.

# %%
fig, ax = plt.subplots(figsize=(30,15))
world.plot(ax=ax, color='lightgray')

df.plot(kind="scatter",
             x = "Longitude",
             y = "Latitude",
             alpha = 0.7,
             s = df["U5 Population ('000s)"]/100,
             label = "U5 Population ('000s)",
             c = "Stunting", 
             cmap = plt.get_cmap("jet"),
             colorbar = True,
            ax = ax)




plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()

plt.show()
# Out:
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /Users/shayanriyaz/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:

# %% [markdown]
# ## Compare two countries of your choice

# %%
fig = plt.figure(figsize=(20,10))

ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

columns_to_remove =  ['U5 Population (\'000s)','Longitude','Latitude']

# %% [markdown]
# ### 18. New DataFrame for Country 1 [GRADED]

# %%
filt = df['Country'] == 'PAKISTAN'

pak_df = df.where(filt)
pak_df = pak_df.drop(columns = columns_to_remove) 
pak_df = pak_df.dropna()
pak_df
# Out:
#       Country  Income Classification  Severe Wasting    Wasting  Overweight  \
# 100  PAKISTAN                    1.0             4.5  14.314286    4.757143
#
#       Stunting  Underweight
# 100  46.671429      33.7375

# %% [markdown]
# ### 19. New DataFrame for Country 2 [GRADED]

# %%
filt = df['Country'] == 'GERMANY'

germ_df = df.where(filt)
germ_df = germ_df.drop(columns = columns_to_remove)
germ_df = germ_df.dropna()
germ_df
# Out:
#     Country  Income Classification  Severe Wasting  Wasting  Overweight  \
# 53  GERMANY                    3.0             0.1     0.65        3.35
#
#     Stunting  Underweight
# 53       1.5          0.8

# %% [markdown]
# ### 20. Plots All features of  both DataFrames [GRADED]

# %%
pak_df.plot(kind = 'bar',x = 'Country',ax = ax1)
germ_df.plot(kind = 'bar',x = 'Country',ax = ax2)

# %%
fig

# %% [markdown]
# ## Appendix

# %% [markdown]
# ### How to Add latitude and Longitude

# %%
from geopy.exc import GeocoderTimedOut 
from geopy.geocoders import Nominatim 
   
# declare an empty list to store 
# latitude and longitude of values  
# of city column 
longitude = [] 
latitude = [] 
   
# function to find the coordinate 
# of a given city  
def findGeocode(city): 
       
    # try and catch is used to overcome 
    # the exception thrown by geolocator 
    # using geocodertimedout   
    try: 
          
        # Specify the user_agent as your 
        # app name it should not be none 
        geolocator = Nominatim(user_agent="your_app_name") 
          
        return geolocator.geocode(city) 
      
    except GeocoderTimedOut: 
          
        return findGeocode(city)     
  
# each value from city column 
# will be fetched and sent to 
# function find_geocode    
for i in (df["Country"]): 
      
    if findGeocode(i) != None: 
           
        loc = findGeocode(i) 
          
        # coordinates returned from  
        # function is stored into 
        # two separate list 
        latitude.append(loc.latitude) 
        longitude.append(loc.longitude) 
       
    # if coordinate for a city not 
    # found, insert "NaN" indicating  
    # missing value  
    else: 
        latitude.append(np.nan) 
        longitude.append(np.nan) 
        
        
df['Latitude'] = latitude
df['Longitude'] = longitude
df.to_csv(r'../malnutrition/malnutrition.csv')
